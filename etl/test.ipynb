# %%
import re
from pytube import Playlist
url_playlist = "https://www.youtube.com/watch?v=gdm322JcuAM&list=PLj_F-FxRi9JX2X2NO_JI69-WZ-izMFFXZ"
# url_playlist = "https://www.youtube.com/watch?v=gJQZQ7Oowsc&list=PLj_F-FxRi9JWb5ZScK0zy0a8M0rIPCQzC"
# url_playlist="https://www.youtube.com/watch?v=I-GIBkCNFmQ&list=PLPP1JwaE5jQZLwOaw04FeBI_G3ATeVOSG"
playlist = Playlist(url_playlist)

# %%
playlist._video_regex = re.compile(r"\"url\":\"(/watch\?v=[\w-]*)")

# %%
len(playlist.video_urls)
# Out:
# 18

# %%
playlist.video_urls[0]
# Out:
# 'https://www.youtube.com/watch?v=gdm322JcuAM'

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import SRTFormatter, TextFormatter

def get_video_id(video_url):
    video_id = video_url.split('v=')[1][:11]
    return video_id

# %%
video_id = get_video_id(playlist.video_urls[0])
video_id
# Out:
# 'gdm322JcuAM'

# %%
transcript = YouTubeTranscriptApi.get_transcript(video_id, languages=['ko'])
" ".join(line['text'] for line in transcript)
# Out:
# '괜찮아 오늘 자라고 있어 말을 좀 적은거 같지만 현재 b 되면 괜찮을 거야 안녕하세요 젊은 정신과 의사들의 솔직하게 의미라고 자상한 정신 건강과 마음이야기 네부타 드립니다 4 오늘 시간에는 꽤 p 성격 어떻게 하면 좀 좋아 하게 할 수 있을지 대해서 얘기를 나누어 볼 건데요 해피 서서 게 어떤 성격이 하는지 설명을 해주신다면 요 우선 항상 내가 단점이 많은 사람이다 라고 생각을 하는게 핵심이 될 수 있고 그 다음에 다른 사람이 나를 봤을 때 그 단점을 발전하고 나를 안 좋게 볼 것이다 어 비판을 할 것이다 이런 걱정과 불안 때문에 대인관계 하는 데서도 긴장이 많이 높고 그런 성격이라고 전개 할 수가 있습니다 흡사 왼쪽 장애다 라고 하면 이런 점때문에 제 일상생활 자체가 많이 힘들 때 진단을 할 수 있을 텐데요 뭐 그 정도가 아닌 털에서 흡수 죽고 부끄럽고 인간에게 어려움을 겪으시는 것은 상당히 많으실 거에요 예를 들어 제가 농구를 좋아하는 데 어디 제모 새로 이제 동아리에 가입한다 든지 하게 되면 차 느 돼 못하는거 특히 뭐 어떡하지 근데 이런 생각에 이제 잘 못하게 되기도 하죠 맞아요 괜히 가지 싫고 맛에는 저같은 경우에도 친한 사람들 굉장히 친한 사람들 하고는 두려움이나 불안 이런게 많지 않은 것 같은데요 약간 거리가 있는 사람들 있잖아요 이런 사람들한테 는 내가 말한게 없이 나 뭐 말 실수를 하지 않을까 그것때문에 그 사람들이 날 미워하거나 좀 안 좋게 보지 않을까 그런 생각때문에 만나는게 약간 꺼려지고 거나 긴장이 되거나 이럴땐 있는 것 같아요 그러다 보니까 참 이거 한 주제에 공감도 많이 되구요 그래서 더 어떻게 하면 좋을지에 대해서 잘 말씀드릴 수 있을 것 같아요 일단 이 회피성 성격은 본인이 불편 불안함을 느끼는 경우가 많아요 마세요 저는 인격 장애에 대해서 전반적으로 말씀드릴 때 인격장애 는 본인이 힘든게 아니라 주변 사람들을 힘들게 한다 이렇게 말씀 드렸지만 회피성 성격은 내가 힘들기 때문에 그만큼 치료에 더 접근을 하려고 하시고 도움을 
# ...

# %% [markdown]
# # youtube playlist

# %%
from youtube import get_youtube_video_info,get_video_urls

url_playlist="https://www.youtube.com/watch?v=gJQZQ7Oowsc&list=PLj_F-FxRi9JWb5ZScK0zy0a8M0rIPCQzC"
video_urls=get_video_urls(url_playlist)
len(video_urls)
# Out:
# 19

# %%
video_info=get_youtube_video_info(video_urls[0])

# %%
video_info
# Out:
# {'video_id': 'gJQZQ7Oowsc',
#  'title': '[정신과 의사들의 대면 상담] Ep 1. "너가 우울증이라고?"라는 말을 듣는 20대 우울증 환자',
#  'upload_date': '20210625',
#  'channel': '정신과의사 뇌부자들',
#  'duration': '18:24',
# ...

# %%
# url, title, channel, caption -> 파일로 저장
import json
info = {
    "url": video_urls[0],
    "title": video_info['title'],
    "channel": video_info['channel'],
    "caption": video_info['caption']
}

with open('video_info.json', 'w', encoding='utf-8') as f:
    json.dump(info, f, ensure_ascii=False, indent=4)

# %%
# 플레이리스트 전체를 json 파일로 저장
import json

video_info=get_youtube_video_info(video_urls[0])
video_info_list=[]
for i in video_urls:
    video_info=get_youtube_video_info(i)
    info = {
        "url": i,
        "title": video_info['title'],
        "channel": video_info['channel'],
        "caption": video_info['caption']
    }
    video_info_list.append(info)
with open('video_info.json', 'w', encoding='utf-8') as f:
    json.dump(video_info_list, f, ensure_ascii=False, indent=4)

# %%
len(video_info_list)
# Out:
# 19

# %%
import pandas as pd
df = pd.read_csv('C:\dev\llm_study_jenny\etl\etl_goodwon\download\뇌부자들 X 콜라보.csv')
df.iloc[0].caption
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Playdata\AppData\Local\Temp\ipykernel_15740\647544029.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('C:\dev\llm_study_jenny\etl\etl_goodwon\download\뇌부자들 X 콜라보.csv')
# ...

# %%
df.shape
# Out:
# (117, 5)
