# %% [markdown]
# # 공통 파일 임포트

# %%
from common.youtube import get_video_urls, get_youtube_video_info
from common.download_youtube_info import main

# %% [markdown]
# # 영상 플레이 리스트

# %%
playlist_urls = [
    {"playlist_title":"뇌부자들 X 콜라보", "url":"https://www.youtube.com/watch?v=J1z0VSQgr1Y&list=PLj_F-FxRi9JUebWWgbd43NTeQVqysROgu"},
    {"playlist_title":"우울증 시리즈", "url":"https://www.youtube.com/watch?v=d4pbQkD6lZM&list=PLj_F-FxRi9JWsEKih54TRK8bjTU9snZfY"},
    {"playlist_title":"정신질환 시리즈", "url":"https://www.youtube.com/watch?v=Dp07klgeqEI&list=PLj_F-FxRi9JWUa7LUeU1WG53cH0wtQ82f"},
    {"playlist_title":"알기 쉬운 인격장애", "url":"https://www.youtube.com/watch?v=gdm322JcuAM&list=PLj_F-FxRi9JX2X2NO_JI69-WZ-izMFFXZ"},
    {"playlist_title":"연애 시리즈", "url":"https://www.youtube.com/watch?v=3vaB2GCjxtA&list=PLj_F-FxRi9JUUAPBjMmdMozq0qBbbcRo4"},
    {"playlist_title":"정신과 약물 시리즈", "url":"https://www.youtube.com/watch?v=eGCUb9nFUjg&list=PLj_F-FxRi9JXO-7Qg2RxFbFeXQvBLcs00"},
    {"playlist_title":"사회 X 정신과", "url":"https://www.youtube.com/watch?v=Fbecjc4gyOY&list=PLj_F-FxRi9JWx7NyTs5oK-Mp3db3XDh8q"},

]

# %%
main(playlist_urls)
# Out:
# downloading..:   0%|          | 0/7 [00:00<?, ?it/s]
